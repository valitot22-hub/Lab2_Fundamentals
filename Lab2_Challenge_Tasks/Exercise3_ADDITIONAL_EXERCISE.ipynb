# %%
# [CELL 3] Notebook "ADDITIONAL EXERCISE"

while True:
    pwd = input("Type 'JOCEL POGI' to exit: ")
    if pwd == "JOCEL POGI":
        print("Unlocked.")
        break
    else:
        print("Access Denied.")
# Out:
# Access Denied.
# Access Denied.
# Unlocked.
