# %%
# [CELL 1] CONFIGURATION

ENGINEER = "Golisao"
STUDENT_ID = "TUPM-25-0803"
SEED_NUM = int(STUDENT_ID[-1])

print(f"Sytem Initialized for: {ENGINEER}")
print(f"Algorithmic Seed Value: {SEED_NUM}")
# Out:
# Sytem Initialized for: Golisao
# Algorithmic Seed Value: 3

# %%
# [CELL 2] ARCHITECTURE TEST

actual = 0.1 + 0.2
print(f"Python stores: {actual}")
print("Result: Perfect Match")
# Out:
# Python stores: 0.30000000000000004
# Result: Perfect Match

# %%
# [CELL 3] ASCII INSPECTION

first_letter = ENGINEER[0]
byte_val = ord(first_letter)

print(f"Character: {first_letter}")
print(f"ASCII Value: {byte_val}")
print(f"Next in Sequence: {chr(byte_val + 1)}")
# Out:
# Character: G
# ASCII Value: 71
# Next in Sequence: H

# %%
# [CELL 4] SANITAZAION

raw_in = input("Enter Name (add messy spaces): ")
clean_in = raw_in.strip().upper()
print(f"Original: '{raw_in}' | Cleaned: '{clean_in}'")
# Out:
# Original: 'Jocel Jhon Golisao' | Cleaned: 'JOCEL JHON GOLISAO'

# %%
# [CELL 5] DATA EXISTENCE

user_input = input("Press Enter (leave empty) or type data: ")

if user_input:
    print(f"Data Detected: {user_input}")
else:
    print("ALERT: No data stream detected.")
# Out:
# ALERT: No data stream detected.

# %%
# [CELL 6] SLICING & PARSING

STUDENT_ID = "TUPM-25-0803"

campus = STUDENT_ID[0:4]
unique_id = STUDENT_ID[8:]

tokens = STUDENT_ID.split("-")

print(f"Campus Code: {campus}")
print(f"Unique Sequence: {unique_id}")
print(f"Token List: {tokens}")
# Out:
# Campus Code: TUPM
# Unique Sequence: 0803
# Token List: ['TUPM', '25', '0803']

# %%
# [CELL 7] MODULO OPERATOR

if SEED_NUM % 2 == 0:
    priority = "LOW (Even Seed)"
else:
    priority = "HIGH (Odd Seed)"

print(f"System Priority: {priority}")
# Out:
# System Priority: HIGH (Odd Seed)

# %%
# [CELL 8] DYNAMIC LIMITS

limit = (SEED_NUM * 10) + 20
print(f"--- SAFETY LIMIT: {limit} ---")

val = int(input("Enter Sensor Reading: "))

if val > limit:
    print("ALERT: Over Limit")
elif val < 5:
    print("ALERT: Low Signal")
else:
    print("STATUS: Nominal")
# Out:
# --- SAFETY LIMIT: 50 ---
# STATUS: Nominal

# %%
# [CELL 9] ROBUST INPUT (Exception Handling)

try:
    voltage = int(input("Enter Voltage (Numeric): "))
    print(f"Voltage Captured: {voltage}V")
except ValueError:
    print("SYSTEM ERROR: Input must be numeric. Resetting to 0.")
    voltage = 0

print(f"System continues... Current Voltage: {voltage}")
# Out:
# SYSTEM ERROR: Input must be numeric. Resetting to 0.
# System continues... Current Voltage: 0

# %%
# [CELL 10] LOGIC GATES

has_power = False

if has_power and (10 / 0 == 0):
    print("System On")
else:
    print("System Off (Short-Circuit Triggered)")
# Out:
# System Off (Short-Circuit Triggered)

# %%
# [CELL 11] FOR LOOP

loops = SEED_NUM + 3
print(f"--- RUNNING {loops} CYCLES ---")

for i in range(1, loops + 1):
    print(f"Cycle {i}/{loops} ... Complete")
# Out:
# --- RUNNING 6 CYCLES ---
# Cycle 1/6 ... Complete
# Cycle 2/6 ... Complete
# Cycle 3/6 ... Complete
# Cycle 4/6 ... Complete
# Cycle 5/6 ... Complete
# Cycle 6/6 ... Complete

# %%
# [CELL 12] NESTED LOOPS

rows = int(tokens[2][0]) 

cols = int(tokens[2][-1]) 

print(f"Generating {rows}x{cols} Matrix:")

for r in range(rows):
    for c in range(cols):
        print("#", END= "")
    print()
# Out:
# Generating 0x3 Matrix:

# %%
# [CELL 13] INPUT VALIDATION

while True:
    pwd = input("Type 'ADMIN' to exit: ")
    if pwd == "ADMIN":
        print("Unlocked.")
        break
    else:
        print("Access Denied.")
# Out:
# Access Denied.
# Access Denied.
# Access Denied.
# Access Denied.
# Unlocked.

# %%
# [CELL 14] FORENSIC HASH CALCULATION

A = byte_val
B = SEED_NUM
C = loops

verification_hash = (A * B) - C

print(f"User: {ENGINEER}")
print(f"Forensic Signature: {verification_hash}")
# Out:
# User: Golisao
# Forensic Signature: 207

# %%
# [CELL 15] Notebook "ADDITIONAL EXERCISE"

target_name = "GOLISAO"
student_id = "TUPM-25-0803"  
seed_num = student_id[-1]        
redacted_name = ""

vowels = "AEIOUaeiou"

for char in target_name:
    if char in vowels:
        redacted_name += seed_num
    else:
        redacted_name += char

print(f"Original Name: {target_name}")
print(f"Seed Number:   {seed_num}")
print(f"Redacted Name: {redacted_name}")
# Out:
# Original Name: GOLISAO
# Seed Number:   3
# Redacted Name: G3L3S33

# %%
# [CELL 16] Notebook "ADDITIONAL EXERCISE"

A = byte_val
B = SEED_NUM
C = loops

verification_hash = (A * B) - C

print(f"User: {ENGINEER}")
print(f"Forensic Signature: {verification_hash}")


first_letter = ENGINEER[0]
byte_val = ord(first_letter)

print(f"ASCII Value: {byte_val}")
# Out:
# User: Golisao
# Forensic Signature: 207
# ASCII Value: 71

# %%
# [CELL 17] Notebook "ADDITIONAL EXERCISE"

while True:
    pwd = input("Type 'JOCEL POGI' to exit: ")
    if pwd == "JOCEL POGI":
        print("Unlocked.")
        break
    else:
        print("Access Denied.")
# Out:
# Access Denied.
# Access Denied.
# Unlocked.
